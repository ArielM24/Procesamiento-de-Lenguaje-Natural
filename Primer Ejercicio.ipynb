# %% [markdown]
# # Imports

# %%
import nltk
from nltk.corpus import brown
from nltk.book import text5
from nltk import FreqDist
from nltk.corpus import wordnet as wn
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# # Ejercicio 1
# Generar las gráficas (acumulatica y no acumulativa) de 1000 palabras del vocabulario de text5

# %%
freqdist = FreqDist(text5)

# %%
freqdist.plot(1000)

# %%
freqdist.plot(1000, cumulative=True)

# %% [markdown]
# # Ejercicio 2
# Imprimir las palabras de text5 cuya longitud sea mayor a 30

# %%
voc = freqdist.keys()
long_words = [w for w in voc if len(w) > 30]
long_words
# Out:
# ['oooooooooooooonnnnnnnnnnnneeeeeeeeeeeeeeesssssssss',
#  'http://forums.talkcity.com/tc-adults/start ',
#  'huuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuuugZ',
#  'wooooooooooooohoooooooooooooooo',
#  '//www.wunderground.com/cgi-bin/findweather/getForecast?query=95953#FIR',
#  ')))))))))))))))))))))))))))))))',
#  'miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee',
#  'backfrontsidewaysandallaroundtheworld',
#  'hahahahahahahahahahahahahahahaha',
#  'cooooooooookiiiiiiiiiiiieeeeeeeeeeee',
#  'HHEEYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY',
#  'llloooozzzzeeerrrrzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz',
#  'wheeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  'BAAAAALLLLLLLLIIIIIIINNNNNNNNNNN']

# %% [markdown]
# # Ejercicio 3
# Generar la distribución condicional para Brown Corpus e imprimir la tabla de frecuencia de las siguientes palabras:
# * love
# * hate
# * speak
# * control
# * fear
# * great
# * president
#
# En los géneros:
# * news
# * romance
# * humor

# %%
cfd = nltk.ConditionalFreqDist(
    (genre, word)
    for genre in brown.categories()
    for word in brown.words(categories=genre))
genres = ['news', 'romance', 'humor']
modals = ['love', 'hate', 'speak', 'control', 'fool', 'great', 'president']
cfd.tabulate(conditions=genres, samples=modals)
# Out:
#              love      hate     speak   control      fool     great president
#    news         3         1         3        22         1        30        53
# romance        32         9        11         2         5        30         9
#   humor         4         0         1         0         0         9         1

# %% [markdown]
# # Ejercicio 4
# Imprimir los synsets de las palabras:
# * computer
# * machine
# * car
# * sandwich

# %%
print("Synsets de computer: \n", wn.synsets('computer'))
print("Synsets de machine: \n", wn.synsets('machine'))
print("Synsets de car: \n", wn.synsets('car'))
print("Synsets de sandwich: \n", wn.synsets('sandwich'))
# Out:
# Synsets de computer:
#  [Synset('computer.n.01'), Synset('calculator.n.01')]
# Synsets de machine:
#  [Synset('machine.n.01'), Synset('machine.n.02'), Synset('machine.n.03'), Synset('machine.n.04'), Synset('machine.n.05'), Synset('car.n.01'), Synset('machine.v.01'), Synset('machine.v.02')]
# Synsets de car:
#  [Synset('car.n.01'), Synset('car.n.02'), Synset('car.n.03'), Synset('car.n.04'), Synset('cable_car.n.01')]
# Synsets de sandwich:
#  [Synset('sandwich.n.01'), Synset('sandwich.v.01'), Synset('sandwich.v.02')]

# %% [markdown]
# Imprimir la similitud entre:
# * computer y machine
# * car y machine
# * car y computer
# * computer y sandwich

# %%
# Guardamos los synsets de cada palabra
cm = wn.synset('computer.n.01')
ma = wn.synset('machine.n.01')
c = wn.synset('car.n.01')
sw = wn.synset('sandwich.n.01')

# Imprimimos las similitudes
print("Similitud entre computer y machine: ", cm.path_similarity(ma))
print("Similitud entre car y machine: ", c.path_similarity(ma))
print("Similitud entre car y computer: ", c.path_similarity(cm))
print("Similitud entre computer y sandwich: ", cm.path_similarity(sw))
# Out:
# Similitud entre computer y machine:  0.5
# Similitud entre car y machine:  0.125
# Similitud entre car y computer:  0.1111111111111111
# Similitud entre computer y sandwich:  0.06666666666666667
